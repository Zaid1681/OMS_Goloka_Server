# %%
import pymongo
from pymongo import MongoClient
from faker import Faker
import random
from datetime import datetime, timedelta

# Connect to MongoDB
mongodb_url = "mongodb+srv://zaidkhan1682:Oms123456@cluster0.a94nkk2.mongodb.net"
client = MongoClient(mongodb_url)
db = client["applicants"]  # Replace "your_database_name" with your actual database name

# Create a Faker instance
fake = Faker()

# Define a function to generate random date of birth
def generate_dob():
    today = datetime.now()
    start_date = today - timedelta(days=365 * 30)  # Assuming age between 20 and 30 years
    dob = fake.date_of_birth(tzinfo=None, minimum_age=20, maximum_age=30)
    # Convert datetime.date to datetime.datetime
    return datetime.combine(dob, datetime.min.time())

# Insert 20 dummy users
for _ in range(20):
    user_data = {
        "username": fake.user_name(),
        "email": fake.email(),
        "password": fake.password(),
        "userRole": random.choice(["Admin", "User"]),
        "name": fake.name(),
        "dateOfBirth": generate_dob(),
        "date": fake.date_this_decade(),
        "gender": random.choice(["Male", "Female", "Other"]),
        "resume": fake.text(),
        "portfolioLink": fake.url(),
        "contactNo": fake.phone_number(),
        "about": fake.text(),
    }
    db.users.insert_one(user_data)

print("Dummy data inserted successfully.")
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# d:\golokaIt\OMS_Goloka_Server\practice.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/d%3A/golokaIt/OMS_Goloka_Server/practice.ipynb#W0sZmlsZQ%3D%3D?line=23'>24</a> for _ in range(20):
#      <a href='vscode-notebook-cell:/d%3A/golokaIt/OMS_Goloka_Server/practice.ipynb#W0sZmlsZQ%3D%3D?line=24'>25</a>     user_data = {
#      <a href='vscode-notebook-cell:/d%3A/golokaIt/OMS_Goloka_Server/practice.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a>         "username": fake.user_name(),
#      <a href='vscode-notebook-cell:/d%3A/golokaIt/OMS_Goloka_Server/practice.ipynb#W0sZmlsZQ%3D%3D?line=26'>27</a>         "email": fake.email(),
#    (...)
#      <a href='vscode-notebook-cell:/d%3A/golokaIt/OMS_Goloka_Server/practice.ipynb#W0sZmlsZQ%3D%3D?line=36'>37</a>         "about": fake.text(),
# ...

# %%
import pymongo
from pymongo import MongoClient
from faker import Faker
import random
from datetime import datetime, timedelta

# Connect to MongoDB
mongodb_url = "mongodb+srv://zaidkhan1682:Oms123456@cluster0.a94nkk2.mongodb.net"
client = MongoClient(mongodb_url)
db = client["applicants"]  # Replace "your_database_name" with your actual database name

# Create a Faker instance
fake = Faker()

# Define a function to generate random date of birth
def generate_dob():
    today = datetime.now()
    start_date = today - timedelta(days=365 * 30)  # Assuming age between 20 and 30 years
    dob = fake.date_of_birth(tzinfo=None, minimum_age=20, maximum_age=30)
    # Ensure the date_of_birth function returns a datetime object
    dob_datetime = datetime.combine(dob, datetime.min.time())
    return dob_datetime

# Insert 20 dummy users
for _ in range(20):
    user_data = {
        "username": fake.user_name(),
        "email": fake.email(),
        "password": fake.password(),
        "userRole": random.choice(["Admin", "User"]),
        "name": fake.name(),
        "dateOfBirth": generate_dob(),
        "date": fake.date_this_decade(),
        "gender": random.choice(["Male", "Female", "Other"]),
        "resume": fake.text(),
        "portfolioLink": fake.url(),
        "contactNo": fake.phone_number(),
        "about": fake.text(),
    }
    db.users.insert_one(user_data)

print("Dummy data inserted successfully.")
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# d:\golokaIt\OMS_Goloka_Server\practice.ipynb Cell 2 line 4
#      <a href='vscode-notebook-cell:/d%3A/golokaIt/OMS_Goloka_Server/practice.ipynb#W1sZmlsZQ%3D%3D?line=24'>25</a> for _ in range(20):
#      <a href='vscode-notebook-cell:/d%3A/golokaIt/OMS_Goloka_Server/practice.ipynb#W1sZmlsZQ%3D%3D?line=25'>26</a>     user_data = {
#      <a href='vscode-notebook-cell:/d%3A/golokaIt/OMS_Goloka_Server/practice.ipynb#W1sZmlsZQ%3D%3D?line=26'>27</a>         "username": fake.user_name(),
#      <a href='vscode-notebook-cell:/d%3A/golokaIt/OMS_Goloka_Server/practice.ipynb#W1sZmlsZQ%3D%3D?line=27'>28</a>         "email": fake.email(),
#    (...)
#      <a href='vscode-notebook-cell:/d%3A/golokaIt/OMS_Goloka_Server/practice.ipynb#W1sZmlsZQ%3D%3D?line=37'>38</a>         "about": fake.text(),
# ...

# %%
import pymongo
from pymongo import MongoClient
from faker import Faker
import random

# Connect to MongoDB
mongodb_url = "mongodb+srv://zaidkhan1682:Oms123456@cluster0.a94nkk2.mongodb.net"
client = MongoClient(mongodb_url)
db = client["oms"]  # Use the "oms" database
collection = db["TechTeam"]  # Use the "TechTeam" collection

# Create a Faker instance with the 'en_IN' locale for Indian names
fake = Faker('en_IN')

# Define a function to generate random date of birth, sometimes returning a random string
def generate_dob():
    # Introduce a random chance (e.g., 10%) to return a random string instead of a datetime object
    if random.random() < 0.1:
        return fake.word()  # Replace with any random string generation logic

    dob = fake.date_of_birth(tzinfo=None, minimum_age=20, maximum_age=30)
    # Ensure the date_of_birth function returns a datetime object
    dob_datetime = dob.strftime("%Y-%m-%d")
    return dob_datetime

# Insert 5 dummy applicants with Indian names and Gmail IDs into the TechTeam collection
for _ in range(5):
    applicant_data = {
        "name": fake.name(),
        "gender": random.choice(["Male", "Female", "Other"]),
        "email": fake.email().split('@')[0] + "@gmail.com",
        "Team": "TechnicalTeam",
        "contactNo": fake.phone_number(),
    }
    collection.insert_one(applicant_data)

print("Dummy data inserted successfully into the TechTeam collection of the oms database for the TechnicalTeam.")
# Out:
# Dummy data inserted successfully into the applicants collection of the oms database.

# %%
import pymongo
from pymongo import MongoClient
from faker import Faker
import random

# Connect to MongoDB
mongodb_url = "mongodb+srv://zaidkhan1682:Oms123456@cluster0.a94nkk2.mongodb.net"
client = MongoClient(mongodb_url)
db = client["test"]  # Use the "oms" database
collection = db["hrteams"]  # Use the "TechTeam" collection

# Create a Faker instance with the 'en_IN' locale for Indian names
fake = Faker('en_IN')

# Define a function to generate random date of birth, sometimes returning a random string
def generate_dob():
    # Introduce a random chance (e.g., 10%) to return a random string instead of a datetime object
    if random.random() < 0.1:
        return fake.word()  # Replace with any random string generation logic

    dob = fake.date_of_birth(tzinfo=None, minimum_age=20, maximum_age=30)
    # Ensure the date_of_birth function returns a datetime object
    dob_datetime = dob.strftime("%Y-%m-%d")
    return dob_datetime

# Insert 5 dummy applicants with Indian names and Gmail IDs into the TechTeam collection
for _ in range(5):
    applicant_data = {
        "name": fake.name(),
        "gender": random.choice(["Male", "Female"]),
        "email": fake.email().split('@')[0] + "@gmail.com",
        "Team": "HrTeam",
        "contactNo": fake.phone_number(),
    }
    collection.insert_one(applicant_data)

print("Dummy data inserted successfully into the TechTeam collection of the oms database for the TechnicalTeam.")
# Out:
# Dummy data inserted successfully into the TechTeam collection of the oms database for the TechnicalTeam.
